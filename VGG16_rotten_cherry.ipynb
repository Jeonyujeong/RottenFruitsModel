# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeonyujeong/RottenFruitsModel/blob/master/VGG16_rotten_cherry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # train dataset 250개씩 개수 맞춘 후 학습결과
#
#
# ```
# [INFO] evaluating network...
#                   precision    recall  f1-score   support
#
#           damage       0.58      0.57      0.58        63
#           normal       0.79      0.62      0.69        66
# spoiled_advanced       0.67      0.86      0.75        78
#    spoiled_early       0.54      0.48      0.51        64
#
#         accuracy                           0.65       271
#        macro avg       0.65      0.63      0.63       271
#     weighted avg       0.65      0.65      0.64       271
#
#
# ```

# %% [markdown]
# # 체리 데이터 가져오기

# %%
# !wget https://github.com/RottenFruitsOSS/DataSet/raw/master/dataset_count_fit.tar.gz
# Out:
# --2020-08-20 12:19:10--  https://github.com/RottenFruitsOSS/DataSet/raw/master/dataset_count_fit.tar.gz
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/RottenFruitsOSS/DataSet/master/dataset_count_fit.tar.gz [following]
# --2020-08-20 12:19:11--  https://raw.githubusercontent.com/RottenFruitsOSS/DataSet/master/dataset_count_fit.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6198630 (5.9M) [application/octet-stream]
# Saving to: ‘dataset_count_fit.tar.gz’
#
# dataset_count_fit.t 100%[===================>]   5.91M  15.5MB/s    in 0.4s
#
# 2020-08-20 12:19:15 (15.5 MB/s) - ‘dataset_count_fit.tar.gz’ saved [6198630/6198630]

# %%
# !tar -xvzf dataset_count_fit.tar.gz
# Out:
# ./test_classification/
# ./test_classification/spoiled_early/
# ./test_classification/spoiled_early/early_742.jpg
# ./test_classification/spoiled_early/early_1365.jpg
# ./test_classification/spoiled_early/early_1061.jpg
# ./test_classification/spoiled_early/early_714.jpg
# ./test_classification/spoiled_early/early_701.jpg
# ./test_classification/spoiled_early/early_1206.jpg
# ./test_classification/spoiled_early/early_961.jpg
# ./test_classification/spoiled_early/early_1393.jpg
# ./test_classification/spoiled_early/early_728.jpg
# ./test_classification/spoiled_early/early_1079.jpg
# ./test_classification/spoiled_early/early_1093.jpg
# ./test_classification/spoiled_early/early_798.jpg
# ./test_classification/spoiled_early/early_1454.jpg
# ./test_classification/spoiled_early/early_1024.jpg
# ./test_classification/spoiled_early/spoiled_170.jpg
# ./test_classification/spoiled_early/early_905.jpg
# ./test_classification/spoiled_early/early_710.jpg
# ./test_classification/spoiled_early/early_1212.jpg
# ./test_classification/spoiled_early/early_735.jpg
# ./test_classification/spoiled_early/early_848.jpg
# ./test_classification/normal/
# ./test_classification/normal/normal_106.jpg
# ./test_classification/normal/normal_195.jpg
# ./test_classification/normal/normal_193.jpg
# ./test_classification/normal/normal_196.jpg
# ./test_classification/normal/normal_198.jpg
# ./test_classification/normal/normal_104.jpg
# ./test_classification/normal/normal_103.jpg
# ./test_classification/normal/normal_101.jpg
# ./test_classification/normal/normal_111.jpg
# ./test_classification/normal/normal_202.jpg
# ./test_classification/normal/normal_112.jpg
# ./test_classification/normal/normal_108.jpg
# ./test_classification/normal/normal_105.jpg
# ./test_classification/normal/normal_199.jpg
# ./test_classification/normal/normal_110.jpg
# ./test_classification/normal/normal_200.jpg
# ./test_classification/normal/normal_203.jpg
# ./test_classification/normal/normal_197.jpg
# ./test_classification/normal/normal_194.jpg
# ./test_classification/normal/normal_109.jpg
# ./test_classification/normal/normal_107.jpg
# ./test_classification/normal/normal_102.jpg
# ./test_classification/damage/
# ./test_classification/damage/damage_141.jpg
# ./test_classification/damage/damage_140.jpg
# ./test_classification/damage/damage_139.jpg
# ./test_classification/damage/damage_201.jpg
# ./test_classification/damage/damage_205.jpg
# ./test_classification/damage/damage_134.jpg
# ./test_classification/damage/damage_208.jpg
# ./test_classification/damage/damage_206.jpg
# ./test_classification/damage/damage_133.jpg
# ./test_classification/damage/damage_207.jpg
# ./test_classification/damage/damage_136.jpg
# ./test_classification/damage/damage_131.jpg
# ./test_classification/damage/damage_200.jpg
# ./test_classification/damage/damage_135.jpg
# ./test_classification/damage/damage_202.jpg
# ./test_classification/damage/damage_132.jpg
# ./test_classification/damage/damage_137.jpg
# ./test_classification/damage/damage_204.jpg
# ./test_classification/damage/damage_209.jpg
# ./test_classification/damage/damage_199.jpg
# ./test_classification/damage/damage_203.jpg
# ./test_classification/damage/damage_138.jpg
# ./test_classification/spoiled_advanced/
# ./test_classification/spoiled_advanced/advanced2_126.jpg
# ./test_classification/spoiled_advanced/advanced2_104.jpg
# ./test_classification/spoiled_advanced/advanced2_133.jpg
# ./test_classification/spoiled_advanced/advanced2_93.jpg
# ./test_classification/spoiled_advanced/advanced_658.jpg
# ./test_classification/spoiled_advanced/advanced_628.jpg
# ./test_classification/spoiled_advanced/advanced_638.jpg
# ./test_classification/spoiled_advanced/advanced2_56.jpg
# ./test_classification/spoiled_advanced/advanced_690.jpg
# ./test_classification/spoiled_advanced/advanced_654.jpg
# ./test_classification/spoiled_advanced/advanced2_116.jpg
# ./test_classification/spoiled_advanced/advanced2_131.jpg
# ./test_classification/spoiled_advanced/advanced2_75.jpg
# ./test_classification/spoiled_advanced/advanced_609.jpg
# ./test_classification/spoiled_advanced/advanced_631.jpg
# ./test_classification/spoiled_advanced/advanced_641.jpg
# ./test_classification/spoiled_advanced/advanced_604.jpg
# ./test_classification/spoiled_advanced/advanced2_96.jpg
# ./test_classification/spoiled_advanced/advanced_681.jpg
# ./test_classification/spoiled_advanced/advanced2_122.jpg
# ./train_classification/
# ./train_classification/spoiled_early/
# ./train_classification/spoiled_early/early_59.jpg
# ./train_classification/spoiled_early/early_1283.jpg
# ./train_classification/spoiled_early/early_1216.jpg
# ./train_classification/spoiled_early/early_1178.jpg
# ./train_classification/spoiled_early/early_1136.jpg
# ./train_classification/spoiled_early/early_1368.jpg
# ./train_classification/spoiled_early/early_1222.jpg
# ./train_classification/spoiled_early/early_1006.jpg
# ./train_classification/spoiled_early/early_1227.jpg
# ./train_classification/spoiled_early/early_1325.jpg
# ./train_classification/spoiled_early/early_1214.jpg
# ./train_classification/spoiled_early/early_1106.jpg
# ./train_classification/spoiled_early/early_1462.jpg
# ./train_classification/spoiled_early/early_33.jpg
# ./train_classification/spoiled_early/early_1123.jpg
# ./train_classification/spoiled_early/early_1052.jpg
# ./train_classification/spoiled_early/early_215.jpg
# ./train_classification/spoiled_early/spoiled_254.jpg
# ./train_classification/spoiled_early/spoiled_205.jpg
# ./train_classification/spoiled_early/early_1291.jpg
# ./train_classification/spoiled_early/early_1129.jpg
# ./train_classification/spoiled_early/early_1043.jpg
# ./train_classification/spoiled_early/early_1389.jpg
# ./train_classification/spoiled_early/early_89.jpg
# ./train_classification/spoiled_early/early_1254.jpg
# ./train_classification/spoiled_early/early_167.jpg
# ./train_classification/spoiled_early/early_1058.jpg
# ./train_classification/spoiled_early/early_1173.jpg
# ./train_classification/spoiled_early/early_212.jpg
# ./train_classification/spoiled_early/early_221.jpg
# ./train_classification/spoiled_early/spoiled_247.jpg
# ./train_classification/spoiled_early/early_998.jpg
# ./train_classification/spoiled_early/spoiled_169.jpg
# ./train_classification/spoiled_early/early_44.jpg
# ./train_classification/spoiled_early/early_1277.jpg
# ./train_classification/spoiled_early/early_1004.jpg
# ./train_classification/spoiled_early/early_1146.jpg
# ./train_classification/spoiled_early/early_1045.jpg
# ./train_classification/spoiled_early/early_1013.jpg
# ./train_classification/spoiled_early/early_1119.jpg
# ./train_classification/spoiled_early/early_1215.jpg
# ./train_classification/spoiled_early/early_1171.jpg
# ./train_classification/spoiled_early/early_1008.jpg
# ./train_classification/spoiled_early/early_1461.jpg
# ./train_classification/spoiled_early/early_1175.jpg
# ./train_classification/spoiled_early/early_102.jpg
# ./train_classification/spoiled_early/early_1391.jpg
# ./train_classification/spoiled_early/spoiled_92.jpg
# ./train_classification/spoiled_early/early_1037.jpg
# ./train_classification/spoiled_early/spoiled_196.jpg
# ./train_classification/spoiled_early/early_1145.jpg
# ./train_classification/spoiled_early/early_198.jpg
# ./train_classification/spoiled_early/early_1308.jpg
# ./train_classification/spoiled_early/early_139.jpg
# ./train_classification/spoiled_early/early_48.jpg
# ./train_classification/spoiled_early/early_1256.jpg
# ./train_classification/spoiled_early/early_1090.jpg
# ./train_classification/spoiled_early/early_12.jpg
# ./train_classification/spoiled_early/early_1148.jpg
# ./train_classification/spoiled_early/early_1080.jpg
# ./train_classification/spoiled_early/early_1324.jpg
# ./train_classification/spoiled_early/early_1157.jpg
# ./train_classification/spoiled_early/early_1177.jpg
# ./train_classification/spoiled_early/early_1113.jpg
# ./train_classification/spoiled_early/early_1040.jpg
# ./train_classification/spoiled_early/early_207.jpg
# ./train_classification/spoiled_early/early_1108.jpg
# ./train_classification/spoiled_early/early_1096.jpg
# ./train_classification/spoiled_early/early_1130.jpg
# ./train_classification/spoiled_early/early_4.jpg
# ./train_classification/spoiled_early/early_1433.jpg
# ./train_classification/spoiled_early/early_76.jpg
# ./train_classification/spoiled_early/early_1075.jpg
# ./train_classification/spoiled_early/early_1245.jpg
# ./train_classification/spoiled_early/early_1229.jpg
# ./train_classification/spoiled_early/early_1126.jpg
# ./train_classification/spoiled_early/early_1153.jpg
# ./train_classification/spoiled_early/early_1221.jpg
# ./train_classification/spoiled_early/early_1170.jpg
# ./train_classification/spoiled_early/spoiled_89.jpg
# ./train_classification/spoiled_early/early_1031.jpg
# ./train_classification/spoiled_early/early_1078.jpg
# ./train_classification/spoiled_early/early_1279.jpg
# ./train_classification/spoiled_early/early_1044.jpg
# ./train_classification/spoiled_early/early_1072.jpg
# ./train_classification/spoiled_early/early_122.jpg
# ./train_classification/spoiled_early/early_1103.jpg
# ./train_classification/spoiled_early/early_1161.jpg
# ./train_classification/spoiled_early/early_1459.jpg
# ./train_classification/spoiled_early/early_151.jpg
# ./train_classification/spoiled_early/early_37.jpg
# ./train_classification/spoiled_early/early_1264.jpg
# ./train_classification/spoiled_early/early_74.jpg
# ./train_classification/spoiled_early/early_1022.jpg
# ./train_classification/spoiled_early/early_1095.jpg
# ./train_classification/spoiled_early/early_1217.jpg
# ./train_classification/spoiled_early/early_17.jpg
# ./train_classification/spoiled_early/early_1240.jpg
# ./train_classification/spoiled_early/early_1098.jpg
# ./train_classification/spoiled_early/early_174.jpg
# ./train_classification/spoiled_early/early_1307.jpg
# ./train_classification/spoiled_early/early_1049.jpg
# ./train_classification/spoiled_early/early_88.jpg
# ./train_classification/spoiled_early/early_23.jpg
# ./train_classification/spoiled_early/early_1116.jpg
# ./train_classification/spoiled_early/early_27.jpg
# ./train_classification/spoiled_early/early_5.jpg
# ./train_classification/spoiled_early/early_1267.jpg
# ./train_classification/spoiled_early/early_1367.jpg
# ./train_classification/spoiled_early/early_1016.jpg
# ./train_classification/spoiled_early/spoiled_232.jpg
# ./train_classification/spoiled_early/early_114.jpg
# ./train_classification/spoiled_early/early_1362.jpg
# ./train_classification/spoiled_early/early_1076.jpg
# ./train_classification/spoiled_early/early_71.jpg
# ./train_classification/spoiled_early/early_1219.jpg
# ./train_classification/spoiled_early/early_1465.jpg
# ./train_classification/spoiled_early/early_34.jpg
# ./train_classification/spoiled_early/early_109.jpg
# ./train_classification/spoiled_early/early_138.jpg
# ./train_classification/spoiled_early/early_1253.jpg
# ./train_classification/spoiled_early/early_119.jpg
# ./train_classification/spoiled_early/early_124.jpg
# ./train_classification/spoiled_early/early_1047.jpg
# ./train_classification/spoiled_early/early_1380.jpg
# ./train_classification/spoiled_early/early_1060.jpg
# ./train_classification/spoiled_early/early_87.jpg
# ./train_classification/spoiled_early/early_56.jpg
# ./train_classification/spoiled_early/early_1378.jpg
# ./train_classification/spoiled_early/spoiled_233.jpg
# ./train_classification/spoiled_early/spoiled_241.jpg
# ./train_classification/spoiled_early/early_6.jpg
# ./train_classification/spoiled_early/early_1041.jpg
# ./train_classification/spoiled_early/early_1150.jpg
# ./train_classification/spoiled_early/early_1026.jpg
# ./train_classification/spoiled_early/early_1059.jpg
# ./train_classification/spoiled_early/early_1457.jpg
# ./train_classification/spoiled_early/early_1370.jpg
# ./train_classification/spoiled_early/spoiled_90.jpg
# ./train_classification/spoiled_early/early_1009.jpg
# ./train_classification/spoiled_early/early_1300.jpg
# ./train_classification/spoiled_early/early_1135.jpg
# ./train_classification/spoiled_early/early_1036.jpg
# ./train_classification/spoiled_early/early_1023.jpg
# ./train_classification/spoiled_early/early_1117.jpg
# ./train_classification/spoiled_early/early_1290.jpg
# ./train_classification/spoiled_early/early_1101.jpg
# ./train_classification/spoiled_early/early_49.jpg
# ./train_classification/spoiled_early/early_1437.jpg
# ./train_classification/spoiled_early/early_1152.jpg
# ./train_classification/spoiled_early/early_1065.jpg
# ./train_classification/spoiled_early/early_1282.jpg
# ./train_classification/spoiled_early/early_1086.jpg
# ./train_classification/spoiled_early/early_1155.jpg
# ./train_classification/spoiled_early/early_1226.jpg
# ./train_classification/spoiled_early/early_1083.jpg
# ./train_classification/spoiled_early/early_1073.jpg
# ./train_classification/spoiled_early/early_1071.jpg
# ./train_classification/spoiled_early/spoiled_206.jpg
# ./train_classification/spoiled_early/early_41.jpg
# ./train_classification/spoiled_early/early_84.jpg
# ./train_classification/spoiled_early/early_1263.jpg
# ./train_classification/spoiled_early/early_1131.jpg
# ./train_classification/spoiled_early/early_63.jpg
# ./train_classification/spoiled_early/early_1015.jpg
# ./train_classification/spoiled_early/early_171.jpg
# ./train_classification/spoiled_early/spoiled_167.jpg
# ./train_classification/spoiled_early/early_1228.jpg
# ./train_classification/spoiled_early/early_1156.jpg
# ./train_classification/spoiled_early/early_1160.jpg
# ./train_classification/spoiled_early/early_146.jpg
# ./train_classification/spoiled_early/early_1114.jpg
# ./train_classification/spoiled_early/early_1048.jpg
# ./train_classification/spoiled_early/early_1057.jpg
# ./train_classification/spoiled_early/early_1084.jpg
# ./train_classification/spoiled_early/early_1082.jpg
# ./train_classification/spoiled_early/early_1000.jpg
# ./train_classification/spoiled_early/early_184.jpg
# ./train_classification/spoiled_early/early_1046.jpg
# ./train_classification/spoiled_early/early_1259.jpg
# ./train_classification/spoiled_early/early_1315.jpg
# ./train_classification/spoiled_early/early_8.jpg
# ./train_classification/spoiled_early/early_1014.jpg
# ./train_classification/spoiled_early/early_1289.jpg
# ./train_classification/spoiled_early/early_35.jpg
# ./train_classification/spoiled_early/early_1007.jpg
# ./train_classification/spoiled_early/early_1088.jpg
# ./train_classification/spoiled_early/early_120.jpg
# ./train_classification/spoiled_early/early_161.jpg
# ./train_classification/spoiled_early/early_94.jpg
# ./train_classification/spoiled_early/early_1139.jpg
# ./train_classification/spoiled_early/early_1176.jpg
# ./train_classification/spoiled_early/early_19.jpg
# ./train_classification/spoiled_early/early_1089.jpg
# ./train_classification/spoiled_early/early_43.jpg
# ./train_classification/spoiled_early/early_1020.jpg
# ./train_classification/spoiled_early/early_1027.jpg
# ./train_classification/spoiled_early/early_218.jpg
# ./train_classification/spoiled_early/early_1091.jpg
# ./train_classification/spoiled_early/early_1293.jpg
# ./train_classification/spoiled_early/spoiled_105.jpg
# ./train_classification/spoiled_early/early_1213.jpg
# ./train_classification/spoiled_early/early_1296.jpg
# ./train_classification/spoiled_early/early_1003.jpg
# ./train_classification/spoiled_early/early_53.jpg
# ./train_classification/spoiled_early/early_1326.jpg
# ./train_classification/spoiled_early/early_186.jpg
# ./train_classification/spoiled_early/early_67.jpg
# ./train_classification/spoiled_early/early_239.jpg
# ./train_classification/spoiled_early/early_1122.jpg
# ./train_classification/spoiled_early/early_1081.jpg
# ./train_classification/spoiled_early/early_1318.jpg
# ./train_classification/spoiled_advanced/advanced_181.jpg
# ./train_classification/spoiled_advanced/advanced2_73.jpg
# ./train_classification/spoiled_advanced/advanced2_27.jpg
# ./train_classification/spoiled_advanced/advanced2_49.jpg
# ./train_classification/spoiled_advanced/advanced2_86.jpg
# ./train_classification/spoiled_advanced/advanced2_34.jpg
# ./train_classification/spoiled_advanced/advanced2_47.jpg
# ./train_classification/spoiled_advanced/advanced_554.jpg
# ./train_classification/spoiled_advanced/advanced_629.jpg
# ./train_classification/spoiled_advanced/advanced_337.jpg
# ./train_classification/spoiled_advanced/advanced2_17.jpg
# ./train_classification/spoiled_advanced/advanced_603.jpg
# ./train_classification/spoiled_advanced/advanced_660.jpg
# ./train_classification/spoiled_advanced/advanced2_11.jpg
# ./train_classification/spoiled_advanced/advanced_656.jpg
# ./train_classification/spoiled_advanced/advanced2_31.jpg
# ./train_classification/spoiled_advanced/advanced2_54.jpg
# ./train_classification/spoiled_advanced/advanced2_16.jpg
# ./train_classification/spoiled_advanced/advanced2_78.jpg
# ./train_classification/spoiled_advanced/advanced_242.jpg
# ./train_classification/spoiled_advanced/advanced2_53.jpg
# ./train_classification/spoiled_advanced/advanced_513.jpg
# ./train_classification/spoiled_advanced/advanced2_130.jpg
# ./train_classification/spoiled_advanced/advanced_685.jpg
# ./train_classification/spoiled_advanced/advanced_189.jpg
# ./train_classification/spoiled_advanced/advanced_664.jpg
# ./train_classification/spoiled_advanced/advanced2_12.jpg
# ./train_classification/spoiled_advanced/advanced_73.jpg
# ./train_classification/spoiled_advanced/advanced_112.jpg
# ./train_classification/spoiled_advanced/advanced_657.jpg
# ./train_classification/spoiled_advanced/advanced2_57.jpg
# ./train_classification/spoiled_advanced/advanced_172.jpg
# ./train_classification/spoiled_advanced/advanced_320.jpg
# ./train_classification/spoiled_advanced/advanced_6.jpg
# ./train_classification/spoiled_advanced/advanced_92.jpg
# ./train_classification/spoiled_advanced/advanced2_63.jpg
# ./train_classification/spoiled_advanced/advanced_151.jpg
# ./train_classification/spoiled_advanced/advanced_205.jpg
# ./train_classification/spoiled_advanced/advanced2_103.jpg
# ./train_classification/spoiled_advanced/advanced2_42.jpg
# ./train_classification/spoiled_advanced/advanced_202.jpg

# %%
# %%shell
#
# mkdir dataset
# mv test_classification/ dataset/
# mv train_classification/ dataset/

# %% [markdown]
# # 설정 값 정의

# %%
# import the necessary packages
import os

# initialize the path to the input directory containing our dataset
# of images
DATASET_PATH = "dataset"

# initialize the class labels in the dataset
CLASSES = ["damage", "normal", "spoiled_advanced", "spoiled_early"]
# CLASSES = ["normal", "spoiled_early"]

# define the size of the training, validation (which comes from the
# train split), and testing splits, respectively
TRAIN_SPLIT = 0.75
VAL_SPLIT = 0.1
TEST_SPLIT = 0.25

# define the minimum learning rate, maximum learning rate, batch size,
# step size, CLR method, and number of epochs
MIN_LR = 1e-6
MAX_LR = 1e-3
BATCH_SIZE = 32
STEP_SIZE = 8
CLR_METHOD = "triangular"
NUM_EPOCHS = 48

# set the path to the serialized model after training
MODEL_PATH = os.path.sep.join(["output", "rotten_cherry.model"])

# define the path to the output learning rate finder plot, training
# history plot and cyclical learning rate plot
LRFIND_PLOT_PATH = os.path.sep.join(["output", "lrfind_plot.png"])
TRAINING_PLOT_PATH = os.path.sep.join(["output", "training_plot.png"])
CLR_PLOT_PATH = os.path.sep.join(["output", "clr_plot.png"])

# %% [markdown]
# # 모듈 임포팅

# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
# matplotlib.use("Agg")

# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import pickle
import cv2
import sys
import os

# %% [markdown]
# # 데이터 로딩과 준비
# ## 파일 로딩 함수

# %%
def load_dataset(datasetPath):
    # grab the paths to all images in our dataset directory and initialize
    # our lists of images and class labels
    imagePaths = list(paths.list_images(datasetPath))
    data = []
    labels = []

    # loop over the image paths
    for imagePath in imagePaths:
        # extract the class label
        label = imagePath.split(os.path.sep)[-2]

        # load the image, convert it to RGB channel ordering, and resize
        # it to be a fixed 224x224 pixels, ignoring aspect ratio
        image = cv2.imread(imagePath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (224, 224))
        # update the data and labels lists, respectively

        data.append(image)
        labels.append(label)

    # convert the data and labels to NumPy arrays
    return np.array(data, dtype="float32"), np.array(labels)

# %% [markdown]
# ## 영상 데이터 파일 로딩

# %%
print("[INFO] processing data...")
data, labels_ = load_dataset(DATASET_PATH)
 
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels_)
# Out:
# [INFO] processing data...

# %%
print(data.shape)
# print(labels_)
# print(labels)
# Out:
# (1084, 224, 224, 3)

# %%
plt.imshow(data[0]/255)
plt.show()

# %% [markdown]
# ## 데이터 쪼개기 및 데이터 증강

# %%
# TRAIN_SPLIT = 0.75
# VAL_SPLIT = 0.1
# TEST_SPLIT = 0.25

# partition the data into training and testing splits
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=TEST_SPLIT, random_state=42)

# take the validation split from the training split
(trainX, valX, trainY, valY) = train_test_split(trainX, trainY,
	test_size=VAL_SPLIT, random_state=84)

# initialize the training data augmentation object
aug = ImageDataGenerator(
	rotation_range=30,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest")

# %% [markdown]
# # 모델 정의

# %% [markdown]
# - VGGNet은 옥스포드 대학의 연구팀 VGG에 의해 개발된 모델이다.
#
# - VGGNet은 16개 또는 19개의 층으로 구성된 모델을 의미한다. (VGG16, VGG19)
#
# ![VGG16 구조](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FK990l%2FbtqwDJ7C54R%2F664Ksm6gyTGBR1wK3YPDFk%2Fimg.png)

# %%
# ImageNet 데이터 셋에서 사전 학습된 VGG16 모델 조정함.

# load the VGG16 network, ensuring the head FC layer sets are left
# off
baseModel = VGG16(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(224, 224, 3)))

# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(512, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(len(CLASSES), activation="softmax")(headModel)

# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)

# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in baseModel.layers:
	layer.trainable = False
	
# compile our model (this needs to be done after our setting our
# layers to being non-trainable
print("[INFO] compiling model...")
opt = SGD(lr=MIN_LR, momentum=0.9)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# [INFO] compiling model...

# %%
# !cat /content/natural-disaster-detection/pyimagesearch/learningratefinder.py

# %%
# import the necessary packages
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
import tempfile

class LearningRateFinder:
	def __init__(self, model, stopFactor=4, beta=0.98):
		# store the model, stop factor, and beta value (for computing
		# a smoothed, average loss)
		self.model = model
		self.stopFactor = stopFactor
		self.beta = beta

		# initialize our list of learning rates and losses,
		# respectively
		self.lrs = []
		self.losses = []

		# initialize our learning rate multiplier, average loss, best
		# loss found thus far, current batch number, and weights file
		self.lrMult = 1
		self.avgLoss = 0
		self.bestLoss = 1e9
		self.batchNum = 0
		self.weightsFile = None

	def reset(self):
		# re-initialize all variables from our constructor
		self.lrs = []
		self.losses = []
		self.lrMult = 1
		self.avgLoss = 0
		self.bestLoss = 1e9
		self.batchNum = 0
		self.weightsFile = None

	def is_data_iter(self, data):
		# define the set of class types we will check for
		iterClasses = ["NumpyArrayIterator", "DirectoryIterator",
			 "DataFrameIterator", "Iterator", "Sequence"]

		# return whether our data is an iterator
		return data.__class__.__name__ in iterClasses

	def on_batch_end(self, batch, logs):
		# grab the current learning rate and add log it to the list of
		# learning rates that we've tried
		lr = K.get_value(self.model.optimizer.lr)
		self.lrs.append(lr)

		# grab the loss at the end of this batch, increment the total
		# number of batches processed, compute the average average
		# loss, smooth it, and update the losses list with the
		# smoothed value
		l = logs["loss"]
		self.batchNum += 1
		self.avgLoss = (self.beta * self.avgLoss) + ((1 - self.beta) * l)
		smooth = self.avgLoss / (1 - (self.beta ** self.batchNum))
		self.losses.append(smooth)

		# compute the maximum loss stopping factor value
		stopLoss = self.stopFactor * self.bestLoss

		# check to see whether the loss has grown too large
		if self.batchNum > 1 and smooth > stopLoss:
			# stop returning and return from the method
			self.model.stop_training = True
			return

		# check to see if the best loss should be updated
		if self.batchNum == 1 or smooth < self.bestLoss:
			self.bestLoss = smooth

		# increase the learning rate
		lr *= self.lrMult
		K.set_value(self.model.optimizer.lr, lr)

	def find(self, trainData, startLR, endLR, epochs=None,
		stepsPerEpoch=None, batchSize=32, sampleSize=2048,
		verbose=1):
		# reset our class-specific variables
		self.reset()

		# determine if we are using a data generator or not
		useGen = self.is_data_iter(trainData)

		# if we're using a generator and the steps per epoch is not
		# supplied, raise an error
		if useGen and stepsPerEpoch is None:
			msg = "Using generator without supplying stepsPerEpoch"
			raise Exception(msg)

		# if we're not using a generator then our entire dataset must
		# already be in memory
		elif not useGen:
			# grab the number of samples in the training data and
			# then derive the number of steps per epoch
			numSamples = len(trainData[0])
			stepsPerEpoch = np.ceil(numSamples / float(batchSize))

		# if no number of training epochs are supplied, compute the
		# training epochs based on a default sample size
		if epochs is None:
			epochs = int(np.ceil(sampleSize / float(stepsPerEpoch)))

		# compute the total number of batch updates that will take
		# place while we are attempting to find a good starting
		# learning rate
		numBatchUpdates = epochs * stepsPerEpoch

		# derive the learning rate multiplier based on the ending
		# learning rate, starting learning rate, and total number of
		# batch updates
		self.lrMult = (endLR / startLR) ** (1.0 / numBatchUpdates)

		# create a temporary file path for the model weights and
		# then save the weights (so we can reset the weights when we
		# are done)
		self.weightsFile = tempfile.mkstemp()[1]
		self.model.save_weights(self.weightsFile)

		# grab the *original* learning rate (so we can reset it
		# later), and then set the *starting* learning rate
		origLR = K.get_value(self.model.optimizer.lr)
		K.set_value(self.model.optimizer.lr, startLR)

		# construct a callback that will be called at the end of each
		# batch, enabling us to increase our learning rate as training
		# progresses
		callback = LambdaCallback(on_batch_end=lambda batch, logs:
			self.on_batch_end(batch, logs))

		# check to see if we are using a data iterator
		if useGen:
			self.model.fit_generator(
				trainData,
				steps_per_epoch=stepsPerEpoch,
				epochs=epochs,
				verbose=verbose,
				callbacks=[callback])

		# otherwise, our entire training data is already in memory
		else:
			# train our model using Keras' fit method
			self.model.fit(
				trainData[0], trainData[1],
				batch_size=batchSize,
				epochs=epochs,
				callbacks=[callback],
				verbose=verbose)

		# restore the original model weights and learning rate
		self.model.load_weights(self.weightsFile)
		K.set_value(self.model.optimizer.lr, origLR)

	def plot_loss(self, skipBegin=10, skipEnd=1, title=""):
		# grab the learning rate and losses values to plot
		lrs = self.lrs[skipBegin:-skipEnd]
		losses = self.losses[skipBegin:-skipEnd]

		# plot the learning rate vs. loss
		plt.plot(lrs, losses)
		plt.xscale("log")
		plt.xlabel("Learning Rate (Log Scale)")
		plt.ylabel("Loss")

		# if the title is not empty, add it to the plot
		if title != "":
			plt.title(title)

# %%
# !mkdir /content/output

# %%
args = {"lr_find": 1}

# check to see if we are attempting to find an optimal learning rate
# before training for the full number of epochs
if args["lr_find"] > 0:
	
	# initialize the learning rate finder and then train with learning
	# rates ranging from 1e-10 to 1e+1
	print("[INFO] finding learning rate...")
	lrf = LearningRateFinder(model)
	lrf.find(
		aug.flow(trainX, trainY, batch_size=BATCH_SIZE),
		1e-10, 1e+1,
		stepsPerEpoch=np.ceil((trainX.shape[0] / float(BATCH_SIZE))),
		epochs=20,
		batchSize=BATCH_SIZE)
 
	# plot the loss for the various learning rates and save the
	# resulting plot to disk
	lrf.plot_loss()
	plt.savefig(LRFIND_PLOT_PATH)
 
	# gracefully exit the script so we can adjust our learning rates
	# in the config and then train the network for our full set of
	# epochs
	print("[INFO] learning rate finder complete")
	print("[INFO] examine plot and adjust learning rates before training")
	sys.exit(0)
# Out:
# [INFO] finding learning rate...
# WARNING:tensorflow:From <ipython-input-18-fa0e2d99ae91>:142: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 23/23 [==============================] - 11s 487ms/step - loss: 4.2008 - accuracy: 0.2654
# Epoch 2/20
# 23/23 [==============================] - 9s 412ms/step - loss: 4.3236 - accuracy: 0.2585
# Epoch 3/20
# 23/23 [==============================] - 9s 402ms/step - loss: 4.1751 - accuracy: 0.2558
# Epoch 4/20
# 23/23 [==============================] - 9s 403ms/step - loss: 3.9925 - accuracy: 0.2845
# Epoch 5/20
# 23/23 [==============================] - 9s 399ms/step - loss: 4.1629 - accuracy: 0.2613
# Epoch 6/20
# 23/23 [==============================] - 9s 402ms/step - loss: 4.0297 - accuracy: 0.2859
# Epoch 7/20
# 23/23 [==============================] - 9s 407ms/step - loss: 4.2229 - accuracy: 0.2668
# Epoch 8/20
# 23/23 [==============================] - 9s 400ms/step - loss: 4.0258 - accuracy: 0.2640
# Epoch 9/20
# 23/23 [==============================] - 9s 398ms/step - loss: 4.1134 - accuracy: 0.2640
# Epoch 10/20
# 23/23 [==============================] - 9s 404ms/step - loss: 3.8883 - accuracy: 0.2750
# Epoch 11/20
# 23/23 [==============================] - 9s 403ms/step - loss: 3.7956 - accuracy: 0.3010
# Epoch 12/20
# 23/23 [==============================] - 9s 396ms/step - loss: 4.6979 - accuracy: 0.2763
# Epoch 13/20
# 23/23 [==============================] - 9s 394ms/step - loss: 4.6895 - accuracy: 0.3311
# Epoch 14/20
# 23/23 [==============================] - 9s 408ms/step - loss: 5.7699 - accuracy: 0.2421
# Epoch 15/20
# 23/23 [==============================] - 9s 405ms/step - loss: 5.7803 - accuracy: 0.2462
# Epoch 16/20
# 23/23 [==============================] - 9s 404ms/step - loss: 5.7803 - accuracy: 0.2462
# Epoch 17/20
# 23/23 [==============================] - 9s 398ms/step - loss: 5.7803 - accuracy: 0.2462
# Epoch 18/20
# 23/23 [==============================] - 9s 398ms/step - loss: 5.7803 - accuracy: 0.2462
# Epoch 19/20
# 23/23 [==============================] - 9s 405ms/step - loss: 5.7803 - accuracy: 0.2462
# Epoch 20/20
# 23/23 [==============================] - 9s 402ms/step - loss: 5.7803 - accuracy: 0.2462
# [INFO] learning rate finder complete
# [INFO] examine plot and adjust learning rates before training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
MIN_LR = 1e-9
MAX_LR = 1e-4

# %% [markdown]
# ![Learning Rate](https://pyimagesearch.com/wp-content/uploads/2019/11/keras_natural_disaster_lrfind_plot.png)

# %%
# !cat /content/natural-disaster-detection/pyimagesearch/clr_callback.py

# %%
from tensorflow.keras.callbacks import *
from tensorflow.keras import backend as K
import numpy as np


class CyclicLR(Callback):
	"""This callback implements a cyclical learning rate policy (CLR).
	The method cycles the learning rate between two boundaries with
	some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
	The amplitude of the cycle can be scaled on a per-iteration or
	per-cycle basis.
	This class has three built-in policies, as put forth in the paper.
	"triangular":
		A basic triangular cycle w/ no amplitude scaling.
	"triangular2":
		A basic triangular cycle that scales initial amplitude by half each cycle.
	"exp_range":
		A cycle that scales initial amplitude by gamma**(cycle iterations) at each
		cycle iteration.
	For more detail, please see paper.

	# Example
		```python
			clr = CyclicLR(base_lr=0.001, max_lr=0.006,
								step_size=2000., mode='triangular')
			model.fit(X_train, Y_train, callbacks=[clr])
		```

	Class also supports custom scaling functions:
		```python
			clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
			clr = CyclicLR(base_lr=0.001, max_lr=0.006,
								step_size=2000., scale_fn=clr_fn,
								scale_mode='cycle')
			model.fit(X_train, Y_train, callbacks=[clr])
		```
	# Arguments
		base_lr: initial learning rate which is the
			lower boundary in the cycle.
		max_lr: upper boundary in the cycle. Functionally,
			it defines the cycle amplitude (max_lr - base_lr).
			The lr at any cycle is the sum of base_lr
			and some scaling of the amplitude; therefore
			max_lr may not actually be reached depending on
			scaling function.
		step_size: number of training iterations per
			half cycle. Authors suggest setting step_size
			2-8 x training iterations in epoch.
		mode: one of {triangular, triangular2, exp_range}.
			Default 'triangular'.
			Values correspond to policies detailed above.
			If scale_fn is not None, this argument is ignored.
		gamma: constant in 'exp_range' scaling function:
			gamma**(cycle iterations)
		scale_fn: Custom scaling policy defined by a single
			argument lambda function, where
			0 <= scale_fn(x) <= 1 for all x >= 0.
			mode paramater is ignored
		scale_mode: {'cycle', 'iterations'}.
			Defines whether scale_fn is evaluated on
			cycle number or cycle iterations (training
			iterations since start of cycle). Default is 'cycle'.
	"""

	def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
				 gamma=1., scale_fn=None, scale_mode='cycle'):
		super(CyclicLR, self).__init__()

		self.base_lr = base_lr
		self.max_lr = max_lr
		self.step_size = step_size
		self.mode = mode
		self.gamma = gamma
		if scale_fn == None:
			if self.mode == 'triangular':
				self.scale_fn = lambda x: 1.
				self.scale_mode = 'cycle'
			elif self.mode == 'triangular2':
				self.scale_fn = lambda x: 1 / (2. ** (x - 1))
				self.scale_mode = 'cycle'
			elif self.mode == 'exp_range':
				self.scale_fn = lambda x: gamma ** (x)
				self.scale_mode = 'iterations'
		else:
			self.scale_fn = scale_fn
			self.scale_mode = scale_mode
		self.clr_iterations = 0.
		self.trn_iterations = 0.
		self.history = {}

		self._reset()

	def _reset(self, new_base_lr=None, new_max_lr=None,
			   new_step_size=None):
		"""Resets cycle iterations.
		Optional boundary/step size adjustment.
		"""
		if new_base_lr != None:
			self.base_lr = new_base_lr
		if new_max_lr != None:
			self.max_lr = new_max_lr
		if new_step_size != None:
			self.step_size = new_step_size
		self.clr_iterations = 0.

	def clr(self):
		cycle = np.floor(1 + self.clr_iterations / (2 * self.step_size))
		x = np.abs(self.clr_iterations / self.step_size - 2 * cycle + 1)
		if self.scale_mode == 'cycle':
			return self.base_lr + (self.max_lr - self.base_lr) * np.maximum(0, (1 - x)) * self.scale_fn(cycle)
		else:
			return self.base_lr + (self.max_lr - self.base_lr) * np.maximum(0, (1 - x)) * self.scale_fn(
				self.clr_iterations)

	def on_train_begin(self, logs={}):
		logs = logs or {}

		if self.clr_iterations == 0:
			K.set_value(self.model.optimizer.lr, self.base_lr)
		else:
			K.set_value(self.model.optimizer.lr, self.clr())

	def on_batch_end(self, epoch, logs=None):

		logs = logs or {}
		self.trn_iterations += 1
		self.clr_iterations += 1

		self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
		self.history.setdefault('iterations', []).append(self.trn_iterations)

		for k, v in logs.items():
			self.history.setdefault(k, []).append(v)

		K.set_value(self.model.optimizer.lr, self.clr())

# %%
# otherwise, we have already defined a learning rate space to train
# over, so compute the step size and initialize the cyclic learning
# rate method
stepSize = STEP_SIZE * (trainX.shape[0] // BATCH_SIZE)
clr = CyclicLR(
	mode=CLR_METHOD,
	base_lr=MIN_LR,
	max_lr=MAX_LR,
	step_size=stepSize)

# train the network
print("[INFO] training network...")
H = model.fit_generator(
	aug.flow(trainX, trainY, batch_size=BATCH_SIZE),
	validation_data=(valX, valY),
	steps_per_epoch=trainX.shape[0] // BATCH_SIZE,
	epochs=NUM_EPOCHS,
	callbacks=[clr],
	verbose=1)
# Out:
# [INFO] training network...
# Epoch 1/48
# Epoch 41/48
# 22/22 [==============================] - 10s 439ms/step - loss: 0.5178 - accuracy: 0.5122 - val_loss: 0.4426 - val_accuracy: 0.5976
# Epoch 42/48
# 22/22 [==============================] - 10s 438ms/step - loss: 0.4863 - accuracy: 0.5708 - val_loss: 0.4278 - val_accuracy: 0.5976
# Epoch 43/48
# 22/22 [==============================] - 10s 434ms/step - loss: 0.4843 - accuracy: 0.5508 - val_loss: 0.4246 - val_accuracy: 0.5854
# Epoch 44/48
# 22/22 [==============================] - 10s 445ms/step - loss: 0.4945 - accuracy: 0.5522 - val_loss: 0.4271 - val_accuracy: 0.5854
# Epoch 45/48
# 22/22 [==============================] - 10s 439ms/step - loss: 0.4589 - accuracy: 0.5637 - val_loss: 0.4338 - val_accuracy: 0.5976
# Epoch 46/48
# 22/22 [==============================] - 10s 443ms/step - loss: 0.4784 - accuracy: 0.5308 - val_loss: 0.4342 - val_accuracy: 0.6098
# Epoch 47/48
# 22/22 [==============================] - 10s 446ms/step - loss: 0.4645 - accuracy: 0.5436 - val_loss: 0.4348 - val_accuracy: 0.5976
# Epoch 48/48
# 22/22 [==============================] - 10s 442ms/step - loss: 0.4735 - accuracy: 0.5594 - val_loss: 0.4346 - val_accuracy: 0.5976

# %%
# evaluate the network and show a classification report
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=BATCH_SIZE)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=CLASSES))

# serialize the model to disk
print("[INFO] serializing network to '{}'...".format(MODEL_PATH))
model.save(MODEL_PATH)
# Out:
# [INFO] evaluating network...
#                   precision    recall  f1-score   support
#
#           damage       0.58      0.57      0.58        63
#           normal       0.79      0.62      0.69        66
# spoiled_advanced       0.67      0.86      0.75        78
#    spoiled_early       0.54      0.48      0.51        64
#
#         accuracy                           0.65       271
#        macro avg       0.65      0.63      0.63       271
#     weighted avg       0.65      0.65      0.64       271
#
# [INFO] serializing network to 'output/rotten_cherry.model'...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: output/rotten_cherry.model/assets

# %% [markdown]
# # 히스토리 확인

# %%
# construct a plot that plots and saves the training history
N = np.arange(0, NUM_EPOCHS)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig(TRAINING_PLOT_PATH)

# plot the learning rate history
N = np.arange(0, len(clr.history["lr"]))
plt.figure()
plt.plot(N, clr.history["lr"])
plt.title("Cyclical Learning Rate (CLR)")
plt.xlabel("Training Iterations")
plt.ylabel("Learning Rate")
plt.savefig(CLR_PLOT_PATH)

# %% [markdown]
# # 이미지 예측

# %%
from tensorflow.keras.models import load_model
from imutils import paths
from IPython.display import Image
import numpy as np
import imutils
import random
import cv2
import os
import matplotlib.pyplot as plt
from IPython.display import Image, display
from google.colab.patches import cv2_imshow

# %%
# !mkdir output/images
# Out:
# mkdir: cannot create directory ‘output/images’: File exists

# %%
MODEL_PATH = "/content/output/rotten_cherry.model"
SAMPLE_SIZE = 5
OUTPUT_IMAGE_PATH = "output/images"

# %%
# load the trained model from disk
print("[INFO] loading model...")
model = load_model(MODEL_PATH)

# grab the paths to the disaster images, respectively
print("[INFO] predicting...")
imagePaths = list(paths.list_images(DATASET_PATH))

# combine the two image path lists, randomly shuffle them, and sample
# them
random.shuffle(imagePaths)
imagePaths = imagePaths[:SAMPLE_SIZE]
print(imagePaths)
print(OUTPUT_IMAGE_PATH)

# loop over the sampled image paths
for (i, imagePath) in enumerate(imagePaths):
	# load the image and clone it
    image = cv2.imread(imagePath)
    image = cv2.resize(image, (224, 224))
    output = image.copy()
 
	# resize the input image to be a fixed 128x128 pixels, ignoring
	# aspect ratio
    image = cv2.resize(image, (244, 244))
    image = image.astype("float32") / 255.0
		
	# make predictions on the image
    preds = model.predict(np.expand_dims(image, axis=0))[0]
    j = np.argmax(preds)
    label = CLASSES[j]

	# draw the activity on the output frame
    text = "activity: {}".format(label)
    output = imutils.resize(output, width=500)
    cv2.putText(output, text, (35, 50), cv2.FONT_HERSHEY_SIMPLEX,
		1.25, (0, 255, 0), 5)

	# write the output image to disk	 
    filename = "{}.png".format(i)
    p = os.path.sep.join([OUTPUT_IMAGE_PATH, filename])
    cv2_imshow(output)
    cv2.imwrite(p, output)
# Out:
# [INFO] loading model...
# [INFO] predicting...
# ['dataset/train_classification/damage/damage_125.jpg', 'dataset/train_classification/spoiled_early/early_1106.jpg', 'dataset/train_classification/normal/normal_169.jpg', 'dataset/train_classification/spoiled_advanced/advanced2_9.jpg', 'dataset/train_classification/spoiled_early/early_1279.jpg']
# output/images
# WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input Tensor("input_1_2:0", shape=(None, 224, 224, 3), dtype=float32), but it was called on an input with incompatible shape (None, 244, 244, 3).
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F216A319668>
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F216B9635F8>
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F216B9635F8>
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F216B565E48>
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F216B565E48>

# %%
# !rm -r output/images/
# !mkdir output/images/

# %%
# !zip -r output.zip ./output/*
# Out:
# updating: output/clr_plot.png (deflated 4%)
# updating: output/images/ (stored 0%)
# updating: output/images/0.png (deflated 14%)
# updating: output/images/3.png (deflated 13%)
# updating: output/images/4.png (deflated 7%)
# updating: output/images/1.png (deflated 12%)
# updating: output/images/2.png (deflated 14%)
# updating: output/lrfind_plot.png (deflated 5%)
# updating: output/rotten_cherry.model/ (stored 0%)
# updating: output/rotten_cherry.model/variables/ (stored 0%)
# updating: output/rotten_cherry.model/variables/variables.data-00000-of-00001 (deflated 34%)
# updating: output/rotten_cherry.model/variables/variables.index (deflated 67%)
# updating: output/rotten_cherry.model/saved_model.pb (deflated 91%)
# updating: output/rotten_cherry.model/assets/ (stored 0%)
# updating: output/training_plot.png (deflated 4%)

# %%
from google.colab import files
files.download("output.zip")

# %% [markdown]
# # 모델 로드

# %%
# import the necessary packages
from tensorflow.keras.models import load_model
from collections import deque
import numpy as np
import argparse
import cv2

# %%
# load the trained model from disk
print("[INFO] loading model and label binarizer...")
model = load_model(MODEL_PATH)
# Out:
# [INFO] loading model and label binarizer...
